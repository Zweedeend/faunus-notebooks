# %% [markdown]
# Present an interactive function explorer with slider widgets.
# Scrub the sliders to change the properties of the ``sin`` curve, or
# type into the title text box to update the title of the plot.
# Use the ``bokeh serve`` command to run the example by executing:
#     bokeh serve sliders.py
# at your command prompt. Then navigate to the URL
#     http://localhost:5006/sliders
# in your browser.

# %%
import numpy as np

from bokeh.io import curdoc, output_notebook, show, push_notebook
from bokeh.layouts import row, widgetbox
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Slider, TextInput
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e5b113f9-f474-448e-8c5c-6e53971d2153">Loading BokehJS ...</span>
#     </div>

# %%
# Set up data
N = 200
x = np.linspace(0, 4*np.pi, N)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))


# Set up plot
plot = figure(plot_height=400, plot_width=400, title="my sine wave",
              tools="crosshair,pan,reset,save,wheel_zoom",
              x_range=[0, 4*np.pi], y_range=[-2.5, 2.5])

plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)


# Set up widgets
text = TextInput(title="title", value='my sine wave')
offset = Slider(title="offset", value=0.0, start=-5.0, end=5.0, step=0.1)
amplitude = Slider(title="amplitude", value=1.0, start=-5.0, end=5.0)
phase = Slider(title="phase", value=0.0, start=0.0, end=2*np.pi)
freq = Slider(title="frequency", value=1.0, start=0.1, end=5.1)

# %%
def printer(attr, old, new):
    print(attr, old, new)
freq.on_change('value', printer)

# %%
frozen_json = fhandle.json

# %%
fhandle.update(fhandle.doc, frozen_json)
push_notebook(handle=fhandle)

# %%
fhandle = show(freq, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c4da4f50-1438-4f9b-9946-480ca8c93ccc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c4da4f50-1438-4f9b-9946-480ca8c93ccc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2085a5f0-6306-4f65-bd2e-9efcc3eca875", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c4da4f50-1438-4f9b-9946-480ca8c93ccc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c4da4f50-1438-4f9b-9946-480ca8c93ccc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a50c8a33-4343-413d-86a9-cf9cc2e3e786":{"roots":{"references":[{"attributes":{"callback":null,"end":5.1,"start":0.1,"title":"frequency","value":1.0},"id":"de9bd844-225f-468c-a338-6cd16844cad7","type":"Slider"}],"root_ids":["de9bd844-225f-468c-a338-6cd16844cad7"]},"title":"Bokeh Application","version":"0.12.4"}};
#             var render_items = [{"docid":"a50c8a33-4343-413d-86a9-cf9cc2e3e786","elementid":"c4da4f50-1438-4f9b-9946-480ca8c93ccc","modelid":"de9bd844-225f-468c-a338-6cd16844cad7","notebook_comms_target":"2085a5f0-6306-4f65-bd2e-9efcc3eca875"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("c4da4f50-1438-4f9b-9946-480ca8c93ccc")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
# Set up callbacks
def update_title(attrname, old, new):
    plot.title.text = text.value

text.on_change('value', update_title)

def update_data(attrname, old, new):
    print('hej')
    # Get the current slider values
    a = amplitude.value
    b = offset.value
    w = phase.value
    k = freq.value

    # Generate the new curve
    x = np.linspace(0, 4*np.pi, N)
    y = a*np.sin(k*x + w) + b

    source.data = dict(x=x, y=y)
    push_notebook(handle=handle)

for w in [offset, amplitude, phase, freq]:
    w.on_change('value', update_data)


# Set up layouts and add to document
inputs = widgetbox(text, offset, amplitude, phase, freq)

# %%
r = row(inputs, plot, width=800)

# %%
handle = show(r,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ab18a762-2dbe-40b5-834c-ca0e01eec8ff"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ab18a762-2dbe-40b5-834c-ca0e01eec8ff").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("53a9d903-9738-4056-9368-1cc4d7dd653f", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ab18a762-2dbe-40b5-834c-ca0e01eec8ff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ab18a762-2dbe-40b5-834c-ca0e01eec8ff' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6c8c217a-1832-4c99-8f9b-f841b898a5f4":{"roots":{"references":[{"attributes":{"plot":{"id":"abb24d69-7a48-4609-b4dc-5222d610727a","subtype":"Figure","type":"Plot"}},"id":"6cbf5123-8a10-48b7-ad4b-32bfebb6ab07","type":"CrosshairTool"},{"attributes":{"plot":{"id":"abb24d69-7a48-4609-b4dc-5222d610727a","subtype":"Figure","type":"Plot"}},"id":"49f42f12-972f-4ed5-b513-289cc45e3245","type":"PanTool"},{"attributes":{"callback":null,"end":5.1,"start":0.1,"title":"frequency","value":1.0},"id":"de9bd844-225f-468c-a338-6cd16844cad7","type":"Slider"},{"attributes":{"plot":{"id":"abb24d69-7a48-4609-b4dc-5222d610727a","subtype":"Figure","type":"Plot"}},"id":"3f431ae0-2fcd-4297-ac2e-8326cca39fe1","type":"ResetTool"},{"attributes":{"plot":{"id":"abb24d69-7a48-4609-b4dc-5222d610727a","subtype":"Figure","type":"Plot"}},"id":"9ffe4447-1d08-4fb4-8db3-0978b790ece0","type":"SaveTool"},{"attributes":{"plot":{"id":"abb24d69-7a48-4609-b4dc-5222d610727a","subtype":"Figure","type":"Plot"}},"id":"eef79acd-fef9-494a-8998-6eba4266649d","type":"WheelZoomTool"},{"attributes":{},"id":"29d559a2-7d24-4778-819a-1e625a194075","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":5.0,"start":-5.0,"title":"amplitude","value":1.0},"id":"4da09266-b612-4cba-859c-65f2d3ddde93","type":"Slider"},{"attributes":{"callback":null,"end":5.0,"start":-5.0,"title":"offset","value":0.0},"id":"d9377be8-a9e4-423b-8f4b-289080abcf70","type":"Slider"},{"attributes":{"children":[{"id":"da9ba02c-f103-49b4-94c9-85f195b0b73f","type":"TextInput"},{"id":"d9377be8-a9e4-423b-8f4b-289080abcf70","type":"Slider"},{"id":"4da09266-b612-4cba-859c-65f2d3ddde93","type":"Slider"},{"id":"27eacf56-fb85-494d-bd8d-389fd114eba2","type":"Slider"},{"id":"de9bd844-225f-468c-a338-6cd16844cad7","type":"Slider"}]},"id":"c28e07f9-e6fd-45bb-8157-5b8081afb663","type":"WidgetBox"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"9598af8e-0f17-4ece-8742-8abb2e5ec8fc","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":6.283185307179586,"title":"phase","value":0.0},"id":"27eacf56-fb85-494d-bd8d-389fd114eba2","type":"Slider"},{"attributes":{"below":[{"id":"7716bb40-eb61-4714-9a8a-0ea30fcb1928","type":"LinearAxis"}],"left":[{"id":"d61c2caf-64f4-4eb6-bb76-b6e1db50648a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"7716bb40-eb61-4714-9a8a-0ea30fcb1928","type":"LinearAxis"},{"id":"48ed253c-0c30-40ee-b63e-e631eca19aca","type":"Grid"},{"id":"d61c2caf-64f4-4eb6-bb76-b6e1db50648a","type":"LinearAxis"},{"id":"4fb8044f-81ec-4443-96c5-0122799625da","type":"Grid"},{"id":"9df60cb6-f9d4-45c6-924c-9c02ead7090b","type":"GlyphRenderer"}],"title":{"id":"f8ccfa08-7ec0-4404-90c3-d2dc6daf4571","type":"Title"},"tool_events":{"id":"f9845624-218f-4f29-adeb-33e71c22503c","type":"ToolEvents"},"toolbar":{"id":"362d395d-8655-4158-95e7-b4cf16333c85","type":"Toolbar"},"x_range":{"id":"938ae377-0289-4c7b-8cf7-5b3494425d94","type":"Range1d"},"y_range":{"id":"23ace00f-a4bd-4f8b-aa29-71463bf7ec38","type":"Range1d"}},"id":"abb24d69-7a48-4609-b4dc-5222d610727a","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"my sine wave"},"id":"f8ccfa08-7ec0-4404-90c3-d2dc6daf4571","type":"Title"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f2bb1a9-9121-4660-af91-0d1f2babc887","type":"Line"},{"attributes":{"callback":null,"end":12.566370614359172},"id":"938ae377-0289-4c7b-8cf7-5b3494425d94","type":"Range1d"},{"attributes":{},"id":"f9845624-218f-4f29-adeb-33e71c22503c","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6cbf5123-8a10-48b7-ad4b-32bfebb6ab07","type":"CrosshairTool"},{"id":"49f42f12-972f-4ed5-b513-289cc45e3245","type":"PanTool"},{"id":"3f431ae0-2fcd-4297-ac2 ...

# %%
handle.json
# Out:
# {'roots': {'references': [{'attributes': {'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'}},
#     'id': '6cbf5123-8a10-48b7-ad4b-32bfebb6ab07',
#     'type': 'CrosshairTool'},
#    {'attributes': {'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'}},
#     'id': '49f42f12-972f-4ed5-b513-289cc45e3245',
#     'type': 'PanTool'},
#    {'attributes': {'callback': None,
#      'end': 5.1,
#      'start': 0.1,
#      'title': 'frequency',
#      'value': 1.0},
#     'id': 'de9bd844-225f-468c-a338-6cd16844cad7',
#     'type': 'Slider'},
#    {'attributes': {'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'}},
#     'id': '3f431ae0-2fcd-4297-ac2e-8326cca39fe1',
#     'type': 'ResetTool'},
#    {'attributes': {'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'}},
#     'id': '9ffe4447-1d08-4fb4-8db3-0978b790ece0',
#     'type': 'SaveTool'},
#    {'attributes': {'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'}},
#     'id': 'eef79acd-fef9-494a-8998-6eba4266649d',
#     'type': 'WheelZoomTool'},
#    {'attributes': {},
#     'id': '29d559a2-7d24-4778-819a-1e625a194075',
#     'type': 'BasicTickFormatter'},
#    {'attributes': {'callback': None,
#      'end': 5.0,
#      'start': -5.0,
#      'title': 'offset',
#      'value': 0.0},
#     'id': 'd9377be8-a9e4-423b-8f4b-289080abcf70',
#     'type': 'Slider'},
#    {'attributes': {'children': [{'id': 'da9ba02c-f103-49b4-94c9-85f195b0b73f',
#        'type': 'TextInput'},
#       {'id': 'd9377be8-a9e4-423b-8f4b-289080abcf70', 'type': 'Slider'},
#       {'id': '4da09266-b612-4cba-859c-65f2d3ddde93', 'type': 'Slider'},
#       {'id': '27eacf56-fb85-494d-bd8d-389fd114eba2', 'type': 'Slider'},
#       {'id': 'de9bd844-225f-468c-a338-6cd16844cad7', 'type': 'Slider'}],
#      'css_classes': None},
#     'id': '7969e00b-d40c-43fa-a00e-b7e2b1b93328',
#     'type': 'WidgetBox'},
#    {'attributes': {'children': [{'id': '7969e00b-d40c-43fa-a00e-b7e2b1b93328',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': '9b284167-7565-4fa7-b6ad-d97e506e1be1',
#     'type': 'Row'},
#    {'attributes': {'children': [{'id': 'da9ba02c-f103-49b4-94c9-85f195b0b73f',
#        'type': 'TextInput'},
#       {'id': 'd9377be8-a9e4-423b-8f4b-289080abcf70', 'type': 'Slider'},
#       {'id': '4da09266-b612-4cba-859c-65f2d3ddde93', 'type': 'Slider'},
#       {'id': '27eacf56-fb85-494d-bd8d-389fd114eba2', 'type': 'Slider'},
#       {'id': 'de9bd844-225f-468c-a338-6cd16844cad7', 'type': 'Slider'}]},
#     'id': 'c28e07f9-e6fd-45bb-8157-5b8081afb663',
#     'type': 'WidgetBox'},
#    {'attributes': {'children': [{'id': '7969e00b-d40c-43fa-a00e-b7e2b1b93328',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': '1a847097-ab6a-40a3-a42e-5206476de4a4',
#     'type': 'Row'},
#    {'attributes': {'children': [{'id': 'c80b5441-1ea6-4ab8-a58b-8ee3be4644e9',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': '42d76061-f579-4e42-a1da-a9408b3b4bda',
#     'type': 'Row'},
#    {'attributes': {'children': [{'id': 'da9ba02c-f103-49b4-94c9-85f195b0b73f',
#        'type': 'TextInput'},
#       {'id': 'd9377be8-a9e4-423b-8f4b-289080abcf70', 'type': 'Slider'},
#       {'id': '4da09266-b612-4cba-859c-65f2d3ddde93', 'type': 'Slider'},
#       {'id': '27eacf56-fb85-494d-bd8d-389fd114eba2', 'type': 'Slider'},
#       {'id': 'de9bd844-225f-468c-a338-6cd16844cad7', 'type': 'Slider'}]},
#     'id': '83aaca45-2f62-4c4c-9718-ba49cea24125',
#     'type': 'WidgetBox'},
#    {'attributes': {'children': [{'id': 'da9ba02c-f103-49b4-94c9-85f195b0b73f',
#        'type': 'TextInput'},
#       {'id': 'd9377be8-a9e4-423b-8f4b-289080abcf70', 'type': 'Slider'},
#       {'id': '4da09266-b612-4cba-859c-65f2d3ddde93', 'type': 'Slider'},
#       {'id': '27eacf56-fb85-494d-bd8d-389fd114eba2', 'type': 'Slider'},
#       {'id': 'de9bd844-225f-468c-a338-6cd16844cad7', 'type': 'Slider'}]},
#     'id': 'c80b5441-1ea6-4ab8-a58b-8ee3be4644e9',
#     'type': 'WidgetBox'},
#    {'attributes': {'children': [{'id': 'c28e07f9-e6fd-45bb-8157-5b8081afb663',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': '4bd7ddeb-2a70-4d02-99c6-df926426c303',
#     'type': 'Row'},
#    {'attributes': {'children': [{'id': '7969e00b-d40c-43fa-a00e-b7e2b1b93328',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': 'd8191c37-3ac9-4970-9edf-48a1d78aa237',
#     'type': 'Row'},
#    {'attributes': {'children': [{'id': '83aaca45-2f62-4c4c-9718-ba49cea24125',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': 'eb82b91b-2920-4618-9a6d-dbb9b97ce317',
#     'type': 'Row'},
#    {'attributes': {'callback': None,
#      'end': 5.0,
#      'start': -5.0,
#      'title': 'amplitude',
#      'value': 1.0},
#     'id': '4da09266-b612-4cba-859c-65f2d3ddde93',
#     'type': 'Slider'},
#    {'attributes': {'children': [{'id': 'f254fe6c-d28d-40b0-a238-88d2a3cf2228',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': '9f7afaea-272a-4d0d-839e-233d88688a9c',
#     'type': 'Row'},
#    {'attributes': {'callback': None,
#      'column_names': ['x', 'y'],
#      'data': {'x': {'__ndarray__': '...',
#        'dtype': 'float64',
#        'shape': [200]},
#       'y': {'__ndarray__': '...',
#        'dtype': 'float64',
#        'shape': [200]}}},
#     'id': '9598af8e-0f17-4ece-8742-8abb2e5ec8fc',
#     'type': 'ColumnDataSource'},
#    {'attributes': {'callback': None,
#      'end': 6.283185307179586,
#      'title': 'phase',
#      'value': 0.0},
#     'id': '27eacf56-fb85-494d-bd8d-389fd114eba2',
#     'type': 'Slider'},
#    {'attributes': {'below': [{'id': '7716bb40-eb61-4714-9a8a-0ea30fcb1928',
#        'type': 'LinearAxis'}],
#      'left': [{'id': 'd61c2caf-64f4-4eb6-bb76-b6e1db50648a',
#        'type': 'LinearAxis'}],
#      'plot_height': 400,
#      'plot_width': 400,
#      'renderers': [{'id': '7716bb40-eb61-4714-9a8a-0ea30fcb1928',
#        'type': 'LinearAxis'},
#       {'id': '48ed253c-0c30-40ee-b63e-e631eca19aca', 'type': 'Grid'},
#       {'id': 'd61c2caf-64f4-4eb6-bb76-b6e1db50648a', 'type': 'LinearAxis'},
#       {'id': '4fb8044f-81ec-4443-96c5-0122799625da', 'type': 'Grid'},
#       {'id': '9df60cb6-f9d4-45c6-924c-9c02ead7090b', 'type': 'GlyphRenderer'}],
#      'title': {'id': 'f8ccfa08-7ec0-4404-90c3-d2dc6daf4571', 'type': 'Title'},
#      'tool_events': {'id': 'f9845624-218f-4f29-adeb-33e71c22503c',
#       'type': 'ToolEvents'},
#      'toolbar': {'id': '362d395d-8655-4158-95e7-b4cf16333c85',
#       'type': 'Toolbar'},
#      'x_range': {'id': '938ae377-0289-4c7b-8cf7-5b3494425d94',
#       'type': 'Range1d'},
#      'y_range': {'id': '23ace00f-a4bd-4f8b-aa29-71463bf7ec38',
#       'type': 'Range1d'}},
#     'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#     'subtype': 'Figure',
#     'type': 'Plot'},
#    {'attributes': {'plot': None, 'text': 'my sine wave'},
#     'id': 'f8ccfa08-7ec0-4404-90c3-d2dc6daf4571',
#     'type': 'Title'},
#    {'attributes': {'line_alpha': {'value': 0.6},
#      'line_color': {'value': '#1f77b4'},
#      'line_width': {'value': 3},
#      'x': {'field': 'x'},
#      'y': {'field': 'y'}},
#     'id': '7f2bb1a9-9121-4660-af91-0d1f2babc887',
#     'type': 'Line'},
#    {'attributes': {'callback': None, 'end': 12.566370614359172},
#     'id': '938ae377-0289-4c7b-8cf7-5b3494425d94',
#     'type': 'Range1d'},
#    {'attributes': {'children': [{'id': 'da9ba02c-f103-49b4-94c9-85f195b0b73f',
#        'type': 'TextInput'},
#       {'id': 'd9377be8-a9e4-423b-8f4b-289080abcf70', 'type': 'Slider'},
#       {'id': '4da09266-b612-4cba-859c-65f2d3ddde93', 'type': 'Slider'},
#       {'id': '27eacf56-fb85-494d-bd8d-389fd114eba2', 'type': 'Slider'},
#       {'id': 'de9bd844-225f-468c-a338-6cd16844cad7', 'type': 'Slider'}]},
#     'id': 'f254fe6c-d28d-40b0-a238-88d2a3cf2228',
#     'type': 'WidgetBox'},
#    {'attributes': {},
#     'id': 'f9845624-218f-4f29-adeb-33e71c22503c',
#     'type': 'ToolEvents'},
#    {'attributes': {'active_drag': 'auto',
#      'active_scroll': 'auto',
#      'active_tap': 'auto',
#      'tools': [{'id': '6cbf5123-8a10-48b7-ad4b-32bfebb6ab07',
#        'type': 'CrosshairTool'},
#       {'id': '49f42f12-972f-4ed5-b513-289cc45e3245', 'type': 'PanTool'},
#       {'id': '3f431ae0-2fcd-4297-ac2e-8326cca39fe1', 'type': 'ResetTool'},
#       {'id': '9ffe4447-1d08-4fb4-8db3-0978b790ece0', 'type': 'SaveTool'},
#       {'id': 'eef79acd-fef9-494a-8998-6eba4266649d',
#        'type': 'WheelZoomTool'}]},
#     'id': '362d395d-8655-4158-95e7-b4cf16333c85',
#     'type': 'Toolbar'},
#    {'attributes': {'children': [{'id': 'f254fe6c-d28d-40b0-a238-88d2a3cf2228',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': '454975f2-5395-4f7f-bac6-75e73552c9be',
#     'type': 'Row'},
#    {'attributes': {'line_alpha': {'value': 0.1},
#      'line_color': {'value': '#1f77b4'},
#      'line_width': {'value': 3},
#      'x': {'field': 'x'},
#      'y': {'field': 'y'}},
#     'id': '5a00f442-b488-4cf5-aed2-de3e973fbbd7',
#     'type': 'Line'},
#    {'attributes': {'formatter': {'id': '29d559a2-7d24-4778-819a-1e625a194075',
#       'type': 'BasicTickFormatter'},
#      'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'},
#      'ticker': {'id': 'cb5390d9-404b-4060-8474-adf9c2caf675',
#       'type': 'BasicTicker'}},
#     'id': '7716bb40-eb61-4714-9a8a-0ea30fcb1928',
#     'type': 'LinearAxis'},
#    {'attributes': {'callback': None, 'end': 2.5, 'start': -2.5},
#     'id': '23ace00f-a4bd-4f8b-aa29-71463bf7ec38',
#     'type': 'Range1d'},
#    {'attributes': {},
#     'id': 'cb5390d9-404b-4060-8474-adf9c2caf675',
#     'type': 'BasicTicker'},
#    {'attributes': {'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'},
#      'ticker': {'id': 'cb5390d9-404b-4060-8474-adf9c2caf675',
#       'type': 'BasicTicker'}},
#     'id': '48ed253c-0c30-40ee-b63e-e631eca19aca',
#     'type': 'Grid'},
#    {'attributes': {'formatter': {'id': 'ba11763a-1d0b-4557-abaa-ad544d11810b',
#       'type': 'BasicTickFormatter'},
#      'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'},
#      'ticker': {'id': '2e4efb79-2b47-40b3-b58a-e56fd8511735',
#       'type': 'BasicTicker'}},
#     'id': 'd61c2caf-64f4-4eb6-bb76-b6e1db50648a',
#     'type': 'LinearAxis'},
#    {'attributes': {},
#     'id': '2e4efb79-2b47-40b3-b58a-e56fd8511735',
#     'type': 'BasicTicker'},
#    {'attributes': {'dimension': 1,
#      'plot': {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#       'subtype': 'Figure',
#       'type': 'Plot'},
#      'ticker': {'id': '2e4efb79-2b47-40b3-b58a-e56fd8511735',
#       'type': 'BasicTicker'}},
#     'id': '4fb8044f-81ec-4443-96c5-0122799625da',
#     'type': 'Grid'},
#    {'attributes': {},
#     'id': 'ba11763a-1d0b-4557-abaa-ad544d11810b',
#     'type': 'BasicTickFormatter'},
#    {'attributes': {'children': [{'id': 'c80b5441-1ea6-4ab8-a58b-8ee3be4644e9',
#        'type': 'WidgetBox'},
#       {'id': 'abb24d69-7a48-4609-b4dc-5222d610727a',
#        'subtype': 'Figure',
#        'type': 'Plot'}],
#      'width': 800},
#     'id': 'f45a14ae-143c-4671-8edf-c50625779ecb',
#     'type': 'Row'},
#    {'attributes': {'callback': None,
#      'title': 'title',
#      'value': 'my sine wave'},
#     'id': 'da9ba02c-f103-49b4-94c9-85f195b0b73f',
#     'type': 'TextInput'},
#    {'attributes': {'data_source': {'id': '9598af8e-0f17-4ece-8742-8abb2e5ec8fc',
#       'type': 'ColumnDataSource'},
#      'glyph': {'id': '7f2bb1a9-9121-4660-af91-0d1f2babc887', 'type': 'Line'},
#      'hover_glyph': None,
#      'nonselection_glyph': {'id': '5a00f442-b488-4cf5-aed2-de3e973fbbd7',
#       'type': 'Line'},
#      'selection_glyph': None},
#     'id': '9df60cb6-f9d4-45c6-924c-9c02ead7090b',
#     'type': 'GlyphRenderer'}],
#   'root_ids': ['454975f2-5395-4f7f-bac6-75e73552c9be',
#    'f254fe6c-d28d-40b0-a238-88d2a3cf2228',
#    '9f7afaea-272a-4d0d-839e-233d88688a9c',
#    '9b284167-7565-4fa7-b6ad-d97e506e1be1',
#    'd8191c37-3ac9-4970-9edf-48a1d78aa237',
#    '1a847097-ab6a-40a3-a42e-5206476de4a4',
#    'f45a14ae-143c-4671-8edf-c50625779ecb',
#    '42d76061-f579-4e42-a1da-a9408b3b4bda',
#    'eb82b91b-2920-4618-9a6d-dbb9b97ce317',
#    '4bd7ddeb-2a70-4d02-99c6-df926426c303']},
#  'title': 'Sliders',
#  'version': '0.12.4'}

# %%
w = r.children[0]

# %%
w.children

# %%
from IPython.html.widgets import interact

# %%
interact(update_data, )
