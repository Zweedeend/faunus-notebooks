# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider
from bokeh.layouts import row

output_notebook()

power = 0.5
x = [1,2,3]
y = [i**power for i in x]

fig = figure()
plt = fig.circle(x, y)

def update_plot(power):
    x = plt.data_source.data['x']
    plt.data_source.data['y'] = [i**power for i in x]
    push_notebook(handle=bokeh_handle)  


##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=0.1, end=1, value=1, step=.05, title="power", callback=callback)
bokeh_handle = show(row(fig, slider), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3343e769-2044-40a5-9990-7e8fcc278736">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="10ebff82-fadd-4009-93ae-8bbc3f9434cc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("10ebff82-fadd-4009-93ae-8bbc3f9434cc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("bc918458-ef68-4104-8f4b-d4fc07d9bbf3", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("10ebff82-fadd-4009-93ae-8bbc3f9434cc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '10ebff82-fadd-4009-93ae-8bbc3f9434cc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"692564c9-b9c1-494e-bc00-23e834f724c6":{"roots":{"references":[{"attributes":{"formatter":{"id":"bb70a25a-e21f-4bcb-8150-ef3f7715c67e","type":"BasicTickFormatter"},"plot":{"id":"7848478e-8665-4e19-99c5-d2b737b6bdf5","subtype":"Figure","type":"Plot"},"ticker":{"id":"d190ad06-61b1-4341-a26f-44e242aee0b2","type":"BasicTicker"}},"id":"fa7654ae-fb81-425b-a36a-de39e0c230a5","type":"LinearAxis"},{"attributes":{},"id":"8f7af496-4414-4590-9ddd-9fb0525b3d65","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"7848478e-8665-4e19-99c5-d2b737b6bdf5","subtype":"Figure","type":"Plot"},{"id":"dcf5c9c2-eaed-4f04-a60b-c22c6105e0a3","type":"WidgetBox"}]},"id":"2b6ea7a0-c06c-4306-a584-6eeb185d4c61","type":"Row"},{"attributes":{"children":[{"id":"cee539cf-a7bc-4d35-9d5b-a4ff2ed95085","type":"Slider"}]},"id":"dcf5c9c2-eaed-4f04-a60b-c22c6105e0a3","type":"WidgetBox"},{"attributes":{"below":[{"id":"fa7654ae-fb81-425b-a36a-de39e0c230a5","type":"LinearAxis"}],"left":[{"id":"289df2ee-8bcc-424d-ba3b-a64aa8ea386d","type":"LinearAxis"}],"renderers":[{"id":"fa7654ae-fb81-425b-a36a-de39e0c230a5","type":"LinearAxis"},{"id":"d2157c3a-19f9-4cb2-ade4-2f3164f0ab81","type":"Grid"},{"id":"289df2ee-8bcc-424d-ba3b-a64aa8ea386d","type":"LinearAxis"},{"id":"6d6b0ebb-4ef3-49b1-831b-91ffaa4001f9","type":"Grid"},{"id":"9ff2b893-20ce-41e8-bf37-f7bc1dcbfee5","type":"BoxAnnotation"},{"id":"99dc2bb8-d9eb-4918-9434-268d72f5f791","type":"GlyphRenderer"}],"title":{"id":"9571267a-7924-467a-b170-db3ff5979ab2","type":"Title"},"tool_events":{"id":"3e21e30d-7a41-4321-99c1-6e8383b5a911","type":"ToolEvents"},"toolbar":{"id":"a508de10-4ff2-4d30-b1e2-e30d3ee7978e","type":"Toolbar"},"x_range":{"id":"de87d6e5-bbf7-40cd-8ec8-20a7619ca820","type":"DataRange1d"},"y_range":{"id":"37121a52-eeb4-482c-989b-f6edb8d4980b","type":"DataRange1d"}},"id":"7848478e-8665-4e19-99c5-d2b737b6bdf5","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"9571267a-7924-467a-b170-db3ff5979ab2","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[1.0,1.4142135623730951,1.7320508075688772]}},"id":"b8820e7f-e9e8-4c34-8fab-719496622b5e","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"37121a52-eeb4-482c-989b-f6edb8d4980b","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1ad532df-3d4d-4ff9-a142-d72cfd127a57","type":"PanTool"},{"id":"8b79ef77-63f7-4ecc-9a53-b578893ad404","type":"WheelZoomTool"},{"id":"18ece81b-a94f-42e3-a6f4-acc8eb3d8f17","type":"BoxZoomTool"},{"id":"af7f82ca-19de-4fa2-b1e9-0ce290556023","type":"SaveTool"},{"id":"403aa1d5-5ff5-44a3-a016-55d74e2df4ec","type":"ResetTool"},{"id":"dea96ebc-4c58-4399-b50f-d7c36feafa87","type":"HelpTool"}]},"id":"a508de10-4ff2-4d30-b1e2-e30d3ee7978e","type":"Toolbar"},{"attributes":{},"id":"3e21e30d-7a41-4321-99c1-6e8383b5a911","type":"ToolEvents"},{"attributes":{},"id":"d190ad06-61b1-4341-a26f-44e242aee0b2","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e02d9aa7-9a30-4890-8866-6a2a43adedec","type":"Circle"},{"attributes":{"plot":{"id":"7848478e-8665-4e19-99c5-d2b737b6bdf5","subtype":"Figure","type":"Plot"},"ticker":{"id":"d190ad06-61b1-4341-a26f-44e242aee0b2","type":"BasicTicker"}},"id":"d2157c3a-19f9-4cb2-ade4-2f3164f0ab81","type":"Grid"},{"attributes":{"callback":null},"id":"de87d6e5-bbf7-40cd-8ec8-20a7619ca820","type":"DataRange1d"},{"attributes":{"formatter":{"id":"8f7af496-4414-4590-9ddd-9fb0525b3d65","type":"BasicTickFormatter"},"plot":{"id":"7848478e-8665-4e19-99c5-d2b737b6bdf5","subtype":"Figure","type":"Plot"},"ticker":{"id":"02efc681-b738-4c3e-a4b5-7dc8ee1c324f","type":"BasicTicker"}},"id":"289df2ee-8bcc-424d-ba3b-a64aa8ea386d","type":"LinearAxis"},{"attributes":{},"id":"02efc681-b738-4c3e-a4b5-7dc8ee1c324f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"7848478 ...
